# %%
#CSV파일
## pandas.read_csv("파일 경로(이름)")

import pandas as pd
import os

os.listdir("./DATA")
# Out:
# ['read_csv_sample.csv']

# %%
file_path = './DATA/read_csv_sample.csv'
print(file_path)
# Out:
# ./DATA/read_csv_sample.csv

# %%
file_path2 = os.path.join('DATA','read_csv_sample.csv')
print(file_path2)
# Out:
# DATA\read_csv_sample.csv

# %%
df1 = pd.read_csv(file_path)
df1
# Out:
#    co  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
df2 = pd.read_csv(file_path,header=None)
df2
# Out:
#     0   1   2   3
# 0  co  c1  c2  c3
# 1   0   1   4   7
# 2   1   2   5   8
# 3   2   3   6   9

# %%
df3 = pd.read_csv(file_path, index_col=None)
df3
# Out:
#    co  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
df4 = pd.read_csv(file_path, index_col='c0')
df4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df4 = pd.read_csv(file_path, index_col='c0')
#       2 df4
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:323, in CParserWrapper.read(self, nrows)
#     320     data = {k: v for k, (i, v) in zip(names, data_tups, strict=False)}
#     322     date_data = self._do_date_conversions(names, data)
# --> 323     index, column_names = self._make_index(alldata, names)
#     325 return index, column_names, date_data
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\base_parser.py:282, in ParserBase._make_index(self, alldata, columns, indexnamerow)
#     280 for idx in self.index_col:
#     281     if isinstance(idx, str):
# --> 282         raise ValueError(f"Index {idx} invalid")
#     283     to_remove.append(idx)
#     284     indexes.append(alldata[idx])
#
# ValueError: Index c0 invalid
