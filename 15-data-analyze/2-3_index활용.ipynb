# %%
#

import pandas as pd

exam_data = {'이름' : ['서준','우현','인아'],
			'수학' :[90,80,70], '영어':[98, 89, 95],
			 '음악' :[85,95,100], '체육' :[100,90,90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
print(df.ndim)
print(df.shape)
# Out:
# 2
# (3, 5)

# %%
# Grouping 에 사용
ndf = df.set_index(['이름'])
ndf2 = ndf.set_index('음악')
ndf3 = ndf.set_index(['수학','음악'])
ndf3
# Out:
#         영어   체육
# 수학 음악
# 90 85   98  100
# 80 95   89   90
# 70 100  95   90

# %%
# 행 인덱스 재배열
dict_data = {
	"c0" : [1,2,3],
	"c1" : [4,5,6],
	"c2" : [7,8,9],
	"c3" : [10,11,12],
	"c4" : [13,14,15]
}

df = pd.DataFrame(dict_data, index = ['r0','r1','r2'])
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
new_index = ['r0', 'r1','r2','r3','r4']
ndf = df.reindex(new_index)
print(ndf)

ndf2 = df.reindex(new_index,fill_value=0)
print(ndf2)
# Out:
#      이름  수학  영어  음악  체육
# r0  NaN NaN NaN NaN NaN
# r1  NaN NaN NaN NaN NaN
# r2  NaN NaN NaN NaN NaN
# r3  NaN NaN NaN NaN NaN
# r4  NaN NaN NaN NaN NaN
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 new_index = ['r0', 'r1','r2','r3','r4']
#       2 ndf = df.reindex(new_index)
#       3 print(ndf)
#       4
# ----> 5 ndf2 = df.reindex(new_index,fill_value=0)
#       6 print(ndf2)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6090, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5855 def reindex(
#    5856     self,
#    5857     labels=None,
#    (...)   5867     tolerance=None,
#    5868 ) -> DataFrame:
#    5869     """
#    5870     Conform DataFrame to new index with optional filling logic.
#    5871
#    (...)   6088     See the :ref:`user guide <basics.reindexing>` for more.
#    6089     """
# -> 6090     return super().reindex(
#    6091         labels=labels,
#    6092         index=index,
#    6093         columns=columns,
#    6094         axis=axis,
#    6095         method=method,
#    6096         level=level,
#    6097         fill_value=fill_value,
#    6098         limit=limit,
#    6099         tolerance=tolerance,
#    6100         copy=copy,
#    6101     )
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:5476, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5473     return self._reindex_multi(axes, fill_value)
#    5475 # perform the reindex on the axes
# -> 5476 return self._reindex_axes(
#    5477     axes, level, limit, tolerance, method, fill_value
#    5478 ).__finalize__(self, method="reindex")
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:5503, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value)
#    5498     new_index, indexer = ax.reindex(
#    5499         labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5500     )
#    5502     axis = self._get_axis_number(a)
# -> 5503     obj = obj._reindex_with_indexers(
#    5504         {axis: [new_index, indexer]},
#    5505         fill_value=fill_value,
#    5506         allow_dups=False,
#    5507     )
#    5509 return obj
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:5547, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, allow_dups)
#    5544         indexer = ensure_platform_int(indexer)
#    5546     # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5547     new_data = new_data.reindex_indexer(
#    5548         index,
#    5549         indexer,
#    5550         axis=baxis,
#    5551         fill_value=fill_value,
#    5552         allow_dups=allow_dups,
#    5553     )
#    5555 if new_data is self._mgr:
#    5556     new_data = new_data.copy(deep=False)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:866, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, only_slice, use_na_proxy)
#     863             new_blocks.append(NumpyBlock(vals, blk.mgr_locs, ndim=2))
#     864         else:
#     865             new_blocks.append(
# --> 866                 blk.take_nd(
#     867                     indexer,
#     868                     axis=1,
#     869                     fill_value=(
#     870                         fill_value if fill_value is not None else blk.fill_value
#     871                     ),
#     872                 )
#     873             )
#     875 new_axes = list(self.axes)
#     876 new_axes[axis] = new_axis
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\blocks.py:1015, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1012     allow_fill = True
#    1014 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1015 new_values = algos.take_nd(
#    1016     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1017 )
#    1019 # Called from three places in managers, all of which satisfy
#    1020 #  these assertions
#    1021 if isinstance(self, ExtensionBlock):
#    1022     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1023     #  algos.take_nd call above.
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\array_algos\take.py:112, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     107         arr = cast("NDArrayBackedExtensionArray", arr)
#     108         return arr.take(
#     109             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     110         )
# --> 112     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     114 arr = np.asarray(arr)
#     115 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\numpy_.py:382, in NumpyExtensionArray.take(self, indices, allow_fill, fill_value, axis)
#     370 def take(
#     371     self,
#     372     indices: TakeIndexer,
#    (...)    376     axis: AxisInt = 0,
#     377 ) -> Self:
#     378     """
#     379     Take entries from this array at each index in a list of indices,
#     380     producing an array containing only those entries.
#     381     """
# --> 382     result = super().take(
#     383         indices, allow_fill=allow_fill, fill_value=fill_value, axis=axis
#     384     )
#     385     # See GH#62448.
#     386     if self.dtype.kind in "iub":
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\_mixins.py:170, in NDArrayBackedExtensionArray.take(self, indices, allow_fill, fill_value, axis)
#     161 def take(
#     162     self,
#     163     indices: TakeIndexer,
#    (...)    167     axis: AxisInt = 0,
#     168 ) -> Self:
#     169     if allow_fill:
# --> 170         fill_value = self._validate_scalar(fill_value)
#     172     new_data = take(
#     173         self._ndarray,
#     174         indices,
#    (...)    177         axis=axis,
#     178     )
#     179     return self._from_backing_data(new_data)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\string_.py:750, in StringArray._validate_scalar(self, value)
#     748     return self.dtype.na_value
#     749 elif not isinstance(value, str):
# --> 750     raise TypeError(
#     751         f"Invalid value '{value}' for dtype '{self.dtype}'. Value should be a "
#     752         f"string or missing value, got '{type(value).__name__}' instead."
#     753     )
#     754 return value
#
# TypeError: Invalid value '0' for dtype 'str'. Value should be a string or missing value, got 'int' instead.
