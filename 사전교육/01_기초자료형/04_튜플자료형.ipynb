# %%
# 튜플은 어떻게 만들까
t1 = ()
t2 = (1,) # l1 = [1]
t3 = (1,2,3)
t4 = 1,2,3
print(type(t4))
print(type(t2))
t5 = 1,
print(type(t5))
t6 = 1
print(type(t6))
t7 = ("a","b",("ab","cd"))
print(type(t7))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
# 튜플의 요소값을 지우거나 변경하려고 할 때 --> 튜플은 삭제와 변경이 불가능하다
t1 = (1,2,"a","b")
#del t1[0] -->불가
#t1[1] = "c" -->불가

# %%
#인덱싱하기
t1 = (1, 2, "a", "b")
t1[2]
# Out:
# 'a'

# %%
#슬라이싱하기
t1 = (1, 2, "a", "b")
t1[2:]
# Out:
# ('a', 'b')

# %%
#튜플 더하기
t1 = (1,2,3) 
t2 = (4,5,6)
print(t1+t2)
print(t1*3)
# Out:
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#튜플의 길이 구하기
t1 = (1,2,3,4,5,6)
len(t1)
# Out:
# 6
