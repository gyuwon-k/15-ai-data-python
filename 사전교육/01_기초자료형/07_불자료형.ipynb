# %%
#불 자료형
a = True
b = False
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
print(1==1)
print(2==1)
print(2>1)
print(1<1)
print(2>=1)
print(2<=1)
print(2!=1)
# Out:
# True
# False
# True
# False
# True
# False
# True

# %%
#자료형의 참과 거짓
print(bool("Python"))
print(bool(""))
print("="*10)
print(bool([1,2,3]))
print(bool(5))
print(bool(0))
print("="*10)
print(bool({}))
print(bool(set()))
# Out:
# True
# False
# ...
# True
# True
# False
# ...
# False
# False

# %%
#논리 연산자
#and 연산자
print(True and True)
print(True and False)
print(False and True)
print(False and False)

print("="*10)        #alt누르고 해당 코드줄 이동 가능
#or 연산자
print(True or True)
print(True or False)
print(False or True)
print(False or False)

print("="*10)
#not 연산자
print(not True)
print(not False)
print(not 1)
print(not 0)

print("="*10)
#활용
x = 5
y = 10
print(x>0 and y>0)
# Out:
# True
# False
# False
# False
# ...
# True
# True
# True
# False
# ...
# False
# True
# False
# True
# ...
# True
