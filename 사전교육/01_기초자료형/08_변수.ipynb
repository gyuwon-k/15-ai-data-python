# %%
#변수
a = 1
b = "Python"
c = [1,2,3]

# %%
#변수의 명명 규칙
# 1. 영문자, 숫자, 언더스코어(_) 만 가능
# 2. 숫자로 변수명을 시작할 수 없음
# 3. 예약어는 사용할 수 없다
# 4. 대소문자 구분

_private = "비공개"
user_name = "ken"
UserName = "ken" # 이런 방식은 잘 안씀

# %%
#변수를 만드는 여러가지 방법
a, b = ('python', 'life')
print(f"{a} ,{type(a)}")
print(f"{b} ,{type(b)}")
# Out:
# python ,<class 'str'>
# life ,<class 'str'>

# %%
[a,b] = ['python', 'life']
print(f"{a}, {type(a)}")
# Out:
# python, <class 'str'>

# %%
a = b = 'python'
print(a)
print(b)
# Out:
# python
# python

# %%
a = 3
b = 5
a, b = b, a
print(a)
print(b)
# Out:
# 5
# 3
